# %%
# https://financedata.github.io/posts/finance-data-reader-users-guide.html 
# !pip install -U finance-datareader
# Out:
# Collecting finance-datareader
#   Downloading finance_datareader-0.9.33-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 4.3 MB/s eta 0:00:011
# Requirement already satisfied: lxml in /home/jeongseokgyu/anaconda3/lib/python3.8/site-packages (from finance-datareader) (4.6.3)
# Requirement already satisfied: requests>=2.3.0 in /home/jeongseokgyu/anaconda3/lib/python3.8/site-packages (from finance-datareader) (2.25.1)
# Requirement already satisfied: pandas>=0.19.2 in /home/jeongseokgyu/anaconda3/lib/python3.8/site-packages (from finance-datareader) (1.2.3)
# Requirement already satisfied: tqdm in /home/jeongseokgyu/anaconda3/lib/python3.8/site-packages (from finance-datareader) (4.59.0)
# Collecting requests-file
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/jeongseokgyu/anaconda3/lib/python3.8/site-packages (from pandas>=0.19.2->finance-datareader) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /home/jeongseokgyu/anaconda3/lib/python3.8/site-packages (from pandas>=0.19.2->finance-datareader) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /home/jeongseokgyu/anaconda3/lib/python3.8/site-packages (from pandas>=0.19.2->finance-datareader) (1.22.2)
# Requirement already satisfied: six>=1.5 in /home/jeongseokgyu/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.19.2->finance-datareader) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/jeongseokgyu/anaconda3/lib/python3.8/site-packages (from requests>=2.3.0->finance-datareader) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jeongseokgyu/anaconda3/lib/python3.8/site-packages (from requests>=2.3.0->finance-datareader) (2022.5.18.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jeongseokgyu/anaconda3/lib/python3.8/site-packages (from requests>=2.3.0->finance-datareader) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/jeongseokgyu/anaconda3/lib/python3.8/site-packages (from requests>=2.3.0->finance-datareader) (4.0.0)
# Installing collected packages: requests-file, finance-datareader
# Successfully installed finance-datareader-0.9.33 requests-file-1.5.1

# %%
import pandas as pd
#import seaborn as sns
import FinanceDataReader as fdr
fdr.__version__
# Out:
# '0.9.33'

# %%
fdr.StockListing?

# %%
fdr.StockListing??

# %%
df_krx = fdr.StockListing("KRX")

# %%
df_krx.head()
# Out:
#    Symbol  Market    Name           Sector             Industry ListingDate  \
# 0  060310  KOSDAQ      3S         전자부품 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1  095570   KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 2  006840   KOSPI   AK홀딩스           기타 금융업                 지주사업  1999-08-11
# 3  054620  KOSDAQ  APS홀딩스           기타 금융업          인터넷 트래픽 솔루션  2001-12-04
# 4  265520  KOSDAQ   AP시스템    특수 목적용 기계 제조업          디스플레이 제조 장비  2017-04-07
#
#   SettleMonth     Representative                       HomePage Region
# 0         03월                김세완           http://www.3sref.com  서울특별시
# 1         12월           박대현, 손삼달         http://www.ajnet.co.kr  서울특별시
# 2         12월  채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3         12월                정기로   http://www.apsholdings.co.kr    경기도
# 4         12월                김영주     http://www.apsystems.co.kr    경기도

# %%
df_krx.shape
# Out:
# (8248, 10)

# %%
df_krx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8248 entries, 0 to 8247
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Symbol          8248 non-null   object
#  1   Market          8248 non-null   object
#  2   Name            8248 non-null   object
#  3   Sector          2499 non-null   object
#  4   Industry        2482 non-null   object
#  5   ListingDate     2499 non-null   datetime64[ns]
#  6   SettleMonth     2499 non-null   object
#  7   Representative  2499 non-null   object
#  8   HomePage        2348 non-null   object
#  9   Region          2499 non-null   object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 708.8+ KB

# %%
df_krx.describe()
# Out:
#         Symbol Market             Name          Sector Industry  \
# count     8248   8248             8248            2499     2482
# unique    8248      3             8248             161     2327
# top     57GAEA  KOSPI  한국H735KOSPI200풋  소프트웨어 개발 및 공급업   기업인수합병
# freq         1   6551                1             151       29
# first      NaN    NaN              NaN             NaN      NaN
# last       NaN    NaN              NaN             NaN      NaN
#
#                 ListingDate SettleMonth Representative  \
# count                  2499        2499           2499
# unique                 1859           8           2383
# top     1976-06-30 00:00:00         12월            김종현
# freq                      8        2437              4
# first   1956-03-03 00:00:00         NaN            NaN
# last    2022-06-03 00:00:00         NaN            NaN
#
#                          HomePage Region
# count                        2348   2499
# unique                       2327     22
# top     http://www.cheryong.co.kr  서울특별시
# freq                            2   1020
# first                         NaN    NaN
# last                          NaN    NaN

# %%
df_krx.to_csv("krx.csv", index = False)

# %%
pd.read_csv("krx.csv")
# Out:
#       Symbol  Market             Name                    Sector  \
# 0     060310  KOSDAQ               3S                  전자부품 제조업
# 1     095570   KOSPI           AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI            AK홀딩스                    기타 금융업
# 3     054620  KOSDAQ           APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ            AP시스템             특수 목적용 기계 제조업
# ...      ...     ...              ...                       ...
# 8243  003280   KOSPI             흥아해운                    해상 운송업
# 8244  037440  KOSDAQ               희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 8245  419890   KOSPI  히어로즈 단기채권ESG액티브                       NaN
# 8246  429870   KOSPI    히어로즈 리츠이지스액티브                       NaN
# 8247  238490  KOSDAQ               힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 2                               지주사업  1999-08-11         12월
# 3                        인터넷 트래픽 솔루션  2001-12-04         12월
# 4                        디스플레이 제조 장비  2017-04-07         12월
# ...                              ...         ...         ...
# 8243                  외항화물운송업(케미컬탱커)  1976-06-29         12월
# 8244                       설계 및 감리용역  2000-02-03         12월
# 8245                             NaN         NaN         NaN
# 8246                             NaN         NaN         NaN
# 8247  OLED Mask 인장기, OLED Mask 검사기 등  2017-07-20         12월
#
#             Representative                       HomePage Region
# 0                      김세완           http://www.3sref.com  서울특별시
# 1                 박대현, 손삼달         http://www.ajnet.co.kr  서울특별시
# 2        채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3                      정기로   http://www.apsholdings.co.kr    경기도
# 4                      김영주     http://www.apsystems.co.kr    경기도
# ...                    ...                            ...    ...
# 8243                   이환구         http://www.heung-a.com  서울특별시
# 8244  정영균, 이목운, 허철호 (각자대표)          http://www.heerim.com  서울특별시
# 8245                   NaN                            NaN    NaN
# 8246                   NaN                            NaN    NaN
# 8247                   김주환          http://www.hims.co.kr  인천광역시
#
# [8248 rows x 10 columns]

# %%
df = pd.read_csv("krx.csv", dtype = {"Symbol": object})

# %%
df.shape
# Out:
# (8248, 10)

# %%
df.head()
# Out:
#    Symbol  Market    Name           Sector             Industry ListingDate  \
# 0  060310  KOSDAQ      3S         전자부품 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1  095570   KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 2  006840   KOSPI   AK홀딩스           기타 금융업                 지주사업  1999-08-11
# 3  054620  KOSDAQ  APS홀딩스           기타 금융업          인터넷 트래픽 솔루션  2001-12-04
# 4  265520  KOSDAQ   AP시스템    특수 목적용 기계 제조업          디스플레이 제조 장비  2017-04-07
#
#   SettleMonth     Representative                       HomePage Region
# 0         03월                김세완           http://www.3sref.com  서울특별시
# 1         12월           박대현, 손삼달         http://www.ajnet.co.kr  서울특별시
# 2         12월  채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3         12월                정기로   http://www.apsholdings.co.kr    경기도
# 4         12월                김영주     http://www.apsystems.co.kr    경기도

# %%
df.tail()
# Out:
#       Symbol  Market             Name                    Sector  \
# 8243  003280   KOSPI             흥아해운                    해상 운송업
# 8244  037440  KOSDAQ               희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 8245  419890   KOSPI  히어로즈 단기채권ESG액티브                       NaN
# 8246  429870   KOSPI    히어로즈 리츠이지스액티브                       NaN
# 8247  238490  KOSDAQ               힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 8243                  외항화물운송업(케미컬탱커)  1976-06-29         12월
# 8244                       설계 및 감리용역  2000-02-03         12월
# 8245                             NaN         NaN         NaN
# 8246                             NaN         NaN         NaN
# 8247  OLED Mask 인장기, OLED Mask 검사기 등  2017-07-20         12월
#
#             Representative                HomePage Region
# 8243                   이환구  http://www.heung-a.com  서울특별시
# 8244  정영균, 이목운, 허철호 (각자대표)   http://www.heerim.com  서울특별시
# 8245                   NaN                     NaN    NaN
# 8246                   NaN                     NaN    NaN
# 8247                   김주환   http://www.hims.co.kr  인천광역시

# %%
df.sample(2)
# Out:
#       Symbol Market             Name Sector Industry ListingDate SettleMonth  \
# 1194  58HA19  KOSPI  KBHA19KOSPI200콜    NaN      NaN         NaN         NaN
# 6705  57H245  KOSPI  한국H245KOSPI200콜    NaN      NaN         NaN         NaN
#
#      Representative HomePage Region
# 1194            NaN      NaN    NaN
# 6705            NaN      NaN    NaN

# %%
# http://data.krx.co.kr/contents/MDC/MDI/mdiLoader/index.cmd?menuId=MDC0201020103
df = fdr.DataReader('005930', '2017', '2021')
df.head()
# Out:
#              Open   High    Low  Close  Volume    Change
# Date
# 2017-01-02  35980  36240  35880  36100   93012  0.001665
# 2017-01-03  36280  36620  36020  36480  147153  0.010526
# 2017-01-04  36500  36520  36100  36160  159435 -0.008772
# 2017-01-05  36060  36060  35540  35560  219349 -0.016593
# 2017-01-06  36180  36440  36040  36200  177619  0.017998

# %%
df['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df = fdr.DataReader('AAPL', '2017-01-01', '2022-04-30')
df.tail()
# Out:
#              Close    Open    High     Low       Volume  Change
# Date
# 2022-04-25  162.88  161.12  163.17  158.46   96050000.0  0.0067
# 2022-04-26  156.80  162.25  162.34  156.72   95620000.0 -0.0373
# 2022-04-27  156.57  155.91  159.79  155.38   88060000.0 -0.0015
# 2022-04-28  163.64  159.25  164.51  158.93  130220000.0  0.0452
# 2022-04-29  157.65  161.84  166.20  157.25  131750000.0 -0.0366

# %%
df['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df = fdr.DataReader('USD/KRW', '1995')
df.tail(10)
# Out:
#               Close     Open     High      Low  Change
# Date
# 2022-05-25  1266.41  1261.14  1271.95  1260.06  0.0043
# 2022-05-26  1260.02  1266.55  1269.73  1259.34 -0.0050
# 2022-05-27  1251.99  1260.29  1262.13  1248.85 -0.0064
# 2022-05-30  1234.85  1251.10  1253.58  1234.55 -0.0137
# 2022-05-31  1242.26  1235.60  1243.89  1234.72  0.0060
# 2022-06-01  1246.89  1242.48  1248.58  1240.29  0.0037
# 2022-06-02  1240.32  1247.23  1255.04  1240.67 -0.0053
# 2022-06-03  1250.58  1241.14  1252.23  1238.47  0.0083
# 2022-06-06  1254.81  1251.53  1255.54  1248.52  0.0034
# 2022-06-07  1255.79  1254.81  1259.96  1254.02  0.0008

# %%
df['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df = fdr.DataReader('CNY/KRW', '1995')
df.tail(10)
# Out:
#              Close    Open    High     Low  Change
# Date
# 2022-05-25  189.19  189.54  190.17  189.01 -0.0016
# 2022-05-26  186.95  189.24  189.40  186.88 -0.0118
# 2022-05-27  186.89  187.01  187.29  186.01 -0.0003
# 2022-05-30  185.37  186.77  187.54  185.35 -0.0081
# 2022-05-31  186.17  185.51  186.71  185.26  0.0043
# 2022-06-01  186.46  186.23  186.74  185.73  0.0016
# 2022-06-02  186.21  186.53  187.63  186.25 -0.0013
# 2022-06-03  187.75  186.35  188.01  185.95  0.0083
# 2022-06-06  188.58  187.91  188.68  187.91  0.0044
# 2022-06-07  188.28  188.58  188.89  188.11 -0.0016

# %%
df['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# 비트코인 원화 가격 (빗썸), 2016년 ~ 현재
df = fdr.DataReader('BTC/KRW', '2016')
df.tail(10)
# Out:
#                Close      Open      High       Low  Volume  Change
# Date
# 2022-05-29  37427000  36981000  37609000  36794000  1100.0  0.0121
# 2022-05-30  39589000  37425000  40000000  37196000  1390.0  0.0578
# 2022-05-31  39900000  39575000  40593000  39323000   890.0  0.0079
# 2022-06-01  37843000  39900000  40089000  37533000  2130.0 -0.0516
# 2022-06-02  38344000  37845000  38656000  37558000   660.0  0.0132
# 2022-06-03  37856000  38346000  38555000  37305000   410.0 -0.0127
# 2022-06-04  37906000  37856000  38092000  37602000   220.0  0.0013
# 2022-06-05  38005000  37906000  38202000  37600000   380.0  0.0026
# 2022-06-06  39589000  38005000  39942000  37975000   620.0  0.0417
# 2022-06-07  37670000  39569000  39588000  37416000  2890.0 -0.0485

# %%
df['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_krx.head()
# Out:
#    Symbol  Market    Name           Sector             Industry ListingDate  \
# 0  060310  KOSDAQ      3S         전자부품 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1  095570   KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 2  006840   KOSPI   AK홀딩스           기타 금융업                 지주사업  1999-08-11
# 3  054620  KOSDAQ  APS홀딩스           기타 금융업          인터넷 트래픽 솔루션  2001-12-04
# 4  265520  KOSDAQ   AP시스템    특수 목적용 기계 제조업          디스플레이 제조 장비  2017-04-07
#
#   SettleMonth     Representative                       HomePage Region
# 0         03월                김세완           http://www.3sref.com  서울특별시
# 1         12월           박대현, 손삼달         http://www.ajnet.co.kr  서울특별시
# 2         12월  채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3         12월                정기로   http://www.apsholdings.co.kr    경기도
# 4         12월                김영주     http://www.apsystems.co.kr    경기도

# %%
df_krx['Sector'].head()
# Out:
# 0           전자부품 제조업
# 1    산업용 기계 및 장비 임대업
# 2             기타 금융업
# 3             기타 금융업
# 4      특수 목적용 기계 제조업
# Name: Sector, dtype: object

# %%
df_krx[['Symbol', 'Name']].head()
# Out:
#    Symbol    Name
# 0  060310      3S
# 1  095570  AJ네트웍스
# 2  006840   AK홀딩스
# 3  054620  APS홀딩스
# 4  265520   AP시스템

# %%
df_krx[['Symbol', 'Name', 'Sector']].head()
# Out:
#    Symbol    Name           Sector
# 0  060310      3S         전자부품 제조업
# 1  095570  AJ네트웍스  산업용 기계 및 장비 임대업
# 2  006840   AK홀딩스           기타 금융업
# 3  054620  APS홀딩스           기타 금융업
# 4  265520   AP시스템    특수 목적용 기계 제조업

# %%
item_name = "삼성전자"
df_krx.loc[df_krx["Name"] == item_name, "Symbol"].tolist()[0]
# 2022-06-02  66600  67000  66400  66700  14959443 -0.010386
# 2022-06-03  67200  67300  66800  66800   8222883  0.001499
# 2022-06-07  66200  66400  65400  65500  19299974 -0.019461

# %%
find_item_list("삼성전자", 2021)
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2021-01-04  81000  84400  80200  83000  38655276  0.024691
# 2021-01-05  81600  83900  81600  83900  35335669  0.010843
# 2021-01-06  83300  84500  82100  82200  42089013 -0.020262
# 2021-01-07  82800  84200  82700  82900  32644642  0.008516
# 2021-01-08  83300  90000  83000  88800  59013307  0.071170
# ...           ...    ...    ...    ...       ...       ...
# 2022-05-30  67500  67800  66900  67700  14255484  0.018045
# 2022-05-31  67500  67500  66700  67400  24365002 -0.004431
# 2022-06-02  66600  67000  66400  66700  14959443 -0.010386
# 2022-06-03  67200  67300  66800  66800   8222883  0.001499
# 2022-06-07  66200  66400  65400  65500  19299974 -0.019461
#
# [352 rows x 6 columns]

# %%
find_item_list("삼성전자", 2017)
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2017-01-02  35980  36240  35880  36100     93012  0.001665
# 2017-01-03  36280  36620  36020  36480    147153  0.010526
# 2017-01-04  36500  36520  36100  36160    159435 -0.008772
# 2017-01-05  36060  36060  35540  35560    219349 -0.016593
# 2017-01-06  36180  36440  36040  36200    177619  0.017998
# ...           ...    ...    ...    ...       ...       ...
# 2022-05-30  67500  67800  66900  67700  14255484  0.018045
# 2022-05-31  67500  67500  66700  67400  24365002 -0.004431
# 2022-06-02  66600  67000  66400  66700  14959443 -0.010386
# 2022-06-03  67200  67300  66800  66800   8222883  0.001499
# 2022-06-07  66200  66400  65400  65500  19299974 -0.019461
#
# [1333 rows x 6 columns]

# %%
stock_daily = find_item_list("삼성전자", 2017)
stock_daily
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2017-01-02  35980  36240  35880  36100     93012  0.001665
# 2017-01-03  36280  36620  36020  36480    147153  0.010526
# 2017-01-04  36500  36520  36100  36160    159435 -0.008772
# 2017-01-05  36060  36060  35540  35560    219349 -0.016593
# 2017-01-06  36180  36440  36040  36200    177619  0.017998
# ...           ...    ...    ...    ...       ...       ...
# 2022-05-30  67500  67800  66900  67700  14255484  0.018045
# 2022-05-31  67500  67500  66700  67400  24365002 -0.004431
# 2022-06-02  66600  67000  66400  66700  14959443 -0.010386
# 2022-06-03  67200  67300  66800  66800   8222883  0.001499
# 2022-06-07  66200  66400  65400  65500  19299974 -0.019461
#
# [1333 rows x 6 columns]

# %%
stock_daily["Close"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
g = stock_daily.plot(subplots=True, figsize=(10, 8))

# %%
stock_daily.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count   1333.000000   1333.000000   1333.000000   1333.000000  1.333000e+03
# mean   56415.069767  56943.135784  55867.244561  56506.729182  1.218716e+07
# std    14100.699515  14187.641929  13995.383331  13807.526491  1.015724e+07
# min        0.000000      0.000000      0.000000  35560.000000  0.000000e+00
# 25%    46100.000000  46450.000000  45600.000000  46050.000000  5.216602e+06
# 50%    51000.000000  51600.000000  50520.000000  51200.000000  1.173690e+07
# 75%    68400.000000  68800.000000  67700.000000  68100.000000  1.692688e+07
# max    90300.000000  96800.000000  89500.000000  91000.000000  9.030618e+07
#
#             Change
# count  1333.000000
# mean      0.000578
# std       0.016158
# min      -0.063877
# 25%      -0.009018
# 50%       0.000000
# 75%       0.009761
# max       0.104706

# %%
stock_daily[["Close", "Volume"]].plot(secondary_y="Volume")
# Out:
# <AxesSubplot:xlabel='Date'>
